# %% [markdown]
# ### Họ và Tên : Vũ Minh Nhật
# ### Lớp : DSEB 64A
# ### ID : 11224897

# %% [markdown]
# ### BAI1

# %%
import re
text = input()
a = re.split(r'[\W\s]', text)
a = [x for x in a if x]
print(a)
print(len(a))
# Out:
# ['Làm', 'ơn', 'đừng', 'trừ', 'điểm', 'em', 'mấy', 'lỗi', 'nhỏ', 'nữa', 'mờ']
# 11

# %% [markdown]
# ### BAI2

# %%
import re
text = input()
a = re.sub(r'\s+', ' ',text)
print(a)
# Out:
# a b c

# %% [markdown]
# ### BAI3

# %%
text = input()
print(text)
def is_palindrome(text):
  nguoclai = text[::-1]
  return text == nguoclai
if is_palindrome(text): print('Is palindrome')
else : print("Isn't palindrome")
# Out:
# level
# Is palindrome

# %% [markdown]
# ### BAI 4

# %%
import re
main_string = input()
sub_string  = input()
match = re.search(sub_string, main_string)
if match :
    print('Tồn tại :' ,match.group())
    print('Tần suất:', len(re.findall(sub_string, main_string)))
else : print('Không tồn tại sub string')
# Out:
# Tồn tại : Vũ
# Tần suất: 2

# %% [markdown]
# ### BAI5

# %%
full_names = ['Phạm Trung Kiên', 'Nguyễn Gia Huy', 'Trần Anh Đức', 'Nguyễn Thu Hà', 'Phạm Quang Đức', 'Lê Tùng Khánh', 'Trần Mạnh Đức', 'Nguyễn Đình Hưng', 'Trần Quốc Hoàn', 'Nguyễn Ánh Dương', 'Nguyễn Thy Linh Giang', 'Nguyễn Ngọc Khánh Hà', 'Đinh Văn Hùng', 'Nguyễn Thị Hiền', 'Phạm Thùy Dương', 'Nguyễn Trung Kiên', 'Vũ Thùy Dương', 'Vũ Tiến Đạt']
k = len(full_names)
a = []
for i in range(k):
    k = full_names[i].split(' ')
    a.append([k[0], i])
a.sort()
for k in a :
    print(full_names[k[1]])
# Out:
# Lê Tùng Khánh
# Nguyễn Gia Huy
# Nguyễn Thu Hà
# Nguyễn Đình Hưng
# Nguyễn Ánh Dương
# Nguyễn Thy Linh Giang
# Nguyễn Ngọc Khánh Hà
# Nguyễn Thị Hiền
# Nguyễn Trung Kiên
# Phạm Trung Kiên
# Phạm Quang Đức
# Phạm Thùy Dương
# Trần Anh Đức
# Trần Mạnh Đức
# Trần Quốc Hoàn
# Vũ Thùy Dương
# Vũ Tiến Đạt
# Đinh Văn Hùng

# %% [markdown]
# ### BAI6

# %%
text = 'Machine learning; (ML) is the study of \ computer algorithms that improve automatically through# experience. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so. Machine{ learning} algorithms are used in a wide variety of applications, such as email filtering and computer() vision, where it is difficult or infeasible to develop conventional algorithms to perform the needed tasks. Machine# learning is closely related to computational *statistics, which focuses on making predictions! using computers. The study of mathematical optimization delivers methods, theory and application domains to the-- field of machine learning. Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning In its application across business problems, machine learning is also referred to as predictive analytics. Machine learning; is the study of \ computer algorithms that improve automatically through# experience'
#A
a = re.sub(r'[^\w\s\.]', '', text)
print(a)
#B
dict_words = re.findall(r'\w+', a.lower())
dict_word = set()
for k in dict_words:
    dict_word.add(k)
dict_words = []
for item in dict_word:
    #print(item)
    dict_words.append(item)
print(dict_words)
#C chịu k hiểu luôn
#D 
a = a.lower()
senteces = a.split('. ')
vector = []
for u in senteces:
    m = u.split(' ')
    m = [x for x in m if x]
    vector1 = [0 for x in range (len(dict_words))]
    for i in range (len(dict_words)):
        for j in m:
            if dict_words[i] == j:
                vector1[i] += 1
    vector.append(vector1)
thu_tu = []
for i in range(len(vector)):
    for j in range(i + 1, len(vector)):
        if i != j:
            tich = 0
            tong1 = 0
            tong2 = 0
            for a1 in range(len(vector[i])):
                tich += vector[i][a1] * vector[j][a1] 
                tong1 += vector[i][a1] * vector[i][a1]
                tong2 += vector[j][a1] * vector[j][a1]
            simi = tich / ((tong1 ** 0.5) + (tong2 ** 0.5))
            thu_tu.append([simi, i, j])
thu_tu.sort()
k = len(thu_tu)
for i in range(k - 1, k - 6, -1):
    #print(thu_tu[i])
    print('Các cặp câu có độ tương thích lớn nhất là: ', thu_tu[i][1], thu_tu[i][2])
    print(senteces[thu_tu[i][1]], ' ', senteces[thu_tu[i][2]])
# Out:
# Machine learning ML is the study of  computer algorithms that improve automatically through experience. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model based on sample data known as training data in order to make predictions or decisions without being explicitly programmed to do so. Machine learning algorithms are used in a wide variety of applications such as email filtering and computer vision where it is difficult or infeasible to develop conventional algorithms to perform the needed tasks. Machine learning is closely related to computational statistics which focuses on making predictions using computers. The study of mathematical optimization delivers methods theory and application domains to the field of machine learning. Data mining is a related field of study focusing on exploratory data analysis through unsupervised learning In its application across business problems machine learning is also referred to as predictive analytics. Machine learning is the study of  computer algorithms that improve automatically through experience
# ['of', 'study', 'improve', 'such', 'needed', 'applications', 'focuses', 'problems', 'sample', 'it', 'theory', 'using', 'as', 'do', 'perform', 'field', 'across', 'algorithms', 'vision', 'focusing', 'programmed', 'through', 'or', 'seen', 'which', 'being', 'so', 'are', 'make', 'experience', 'order', 'application', 'on', 'a', 'decisions', 'computer', 'optimization', 'computational', 'related', 'domains', 'machine', 'unsupervised', 'based', 'known', 'artificial', 'is', 'data', 'mathematical', 'used', 'build', 'tasks', 'where', 'mining', 'delivers', 'predictive', 'the', 'intelligence', 'develop', 'statistics', 'making', 'ml', 'exploratory', 'also', 'closely', 'email', 'methods', 'wide', 'business', 'predictions', 'difficult', 'subset', 'its', 'analysis', 'learning', 'computers', 'training', 'without', 'explicitly', 'variety', 'infeasible', 'in', 'that', 'filtering', 'model', 'conventional', 'and', 'analytics', 'to', 'automatically', 'referred']
# Các cặp câu có độ tương thích lớn nhất là:  0 7
# machine learning ml is the study of  computer algorithms that improve automatically through experience   machine learning is the study of  computer algorithms that improve automatically through experience
# Các cặp câu có độ tương thích lớn nhất là:  2 6
# machine learning algorithms build a mathematical model based on sample data known as training data in order to make predictions or decisions without being explicitly programmed to do so   data mining is a related field of study focusing on exploratory data analysis through unsupervised learning in its application across business problems machine learning is also referred to as predictive analytics
# Các cặp câu có độ tương thích lớn nhất là:  2 3
# machine learning algorithms build a mathematical model based on sample data known as training data in order to make predictions or decisions without being explicitly programmed to do so   machine learning algorithms are used in a wide variety of applications such as email filtering and computer vision where it is difficult or infeasible to develop conventional algorithms to perform the needed tasks
# Các cặp câu có độ tương thích lớn nhất là:  3 6
# machine learning algorithms are used in a wide variety of applications such as email filtering and computer vision where it is difficult or infeasible to develop conventional algorithms to perform the needed tasks   data mining is a related field of study focusing on exploratory data analysis through unsupervised learning in its application across business problems machine learning is also referred to as predictive analytics
# Các cặp câu có độ tương thích lớn nhất là:  5 7
# the study of mathematical optimization delivers methods theory and application domains to the field of machine learning   machine learning is the study of  computer algorithms that improve automatically through experience

# %% [markdown]
# ### BAI7

# %%
import re
with open("Example_Regex.txt", encoding="utf-16") as file:
    txt = file.read()
partern = r"(\d+)\n([\w\s]+)\n(\d{2}/\d{2}/\d{4})\n([\w\s]+)\n([\w\.]+@[\w\.]+)"
taphop = re.findall(partern, txt)
sdt = re.findall(r"\d{10}|\d{5}\s\d{3}\s\d{3}|\d{5}\.\d{3}\.\d{3}" , txt)
for hoten in taphop:
    a = [x for x in hoten[1].split('\n') if x]
    print(a)
for ngaysinh in taphop:
    print(ngaysinh[2])
for email in taphop:
    print(email[4])
print(sdt)
for k in sdt:
    a = re.findall(r"\d", k)
    sum = 0
    for i in a:
        sum += int(i)
    if sum % 10 == 9:
        u = k
        k = '(.*)' + u
        f = re.findall(k, txt)
        print(f)
# Out:
# ['Vũ Văn Trường']
# ['Lương Duy Quyền']
# ['Nguyễn Thanh Hòa']
# ['Vũ Thị Loan']
# ['Lã Thị Hương Giang']
# ['Nguyễn Thị Linh']
# ['Bùi Thị Hải Yến']
# ['Phạm Thị Oanh']
# ['Trần Thị Nam']
# ['Tống Thị Ngọc Lan']
# ['Dương Thị Lan Hương']
# ['Trần Việt Hùng']
# ['Hoàng Quốc Hùng']
# ['Nguyễn Thị Thùy Dung']
# ['Nguyễn Văn Lĩnh']
# ['Trần Thị Phương Thảo']
# ['Nguyễn Xuân Thuấn']
# ['Đặng Hữu Việt']
# ['Vũ Thị Kiều Anh']
# ['Nguyễn Thị Vẻ']
# ['Phạm Xuân Giới']
# ['Trần Gia Long']
# ['An Quang Hiển']
# ['Lê Văn Hệ']
# ['Nguyễn Văn Anh']
# ['Hoàng Quý Thu']
# ['Phạm Minh Tứ']
# ['Nguyễn Quang Chiến']
# ['Nguyễn Thị Chinh']
# ['Nguyễn Thị Tuyết']
# ['Đinh Thị Quyên']
# ['Nguyễn Thị Minh Ngọc']
# ['Nguyễn Thị Thảo']
# ['Phùng Thị Thao']
# ['Trương Ngọc Dương']
# ['Phạm Văn Cường']
# ['Phạm Xuân Nguyện']
# ['Vũ Thị Quyên']
# ['Nguyễn Hữu Tiến']
# ['Trương Tiến Phụng']
# ['Lã Đăng Hiệp']
# ['Hoàng Thị Kim Thao']
# ['Đinh Thị Dương Quỳnh']
# ['Phạm Duy Hưng']
# ['Trần Thị Hà Tâm']
# ['Phạm Xuân Lê Đồng']
# ['Lâm Ngọc Cương']
# ['Trịnh Xuân Quỳnh']
# ['Ninh Tiến Nam']
# ['Phạm Thu Thủy']
# ['Vũ Thị Hà']
# ['Trịnh Thị Hoài Thanh']
# ['Trần Thị Huyền Phương']
# ['Vũ Phương Thảo']
# ['An Thị Ngọc Lý']
# ['Nguyễn Thị Thu']
# ['Đỗ Thị Bích Thủy']
# ['Lê Thị Huệ']
# ['Phạm Thị Loan']
# ['Lương Thị Tú']
# ['Đỗ Thị Hồng Thu']
# ['Nguyễn Hồng Thủy']
# ['Nguyễn Thị Hằng']
# ['Lê Thị Thu Hoài']
# ['Phạm Thị Hồng Tâm']
# ['Đàm Thu Vân']
# ['Bùi Thị Hồng Giang']
# ['Nguyễn Thị Hồng Nhung']
# ['Vũ Thị Tuyết Mai']
# ['Phạm Thị Thu Thủy']
# ['Dương Thị Dung']
# ['Trần Thị Thu']
# ['Ngô Thị Huệ']
# ['Trần Thị Hiên']
# ['Lê Thị Hiệu']
# ['Vũ Thị Hường']
# ['Bùi Lê Nhật']
# ['Phạm Văn Cường']
# ['Lê Thị Hồng Hạnh']
# ['Vũ Thị Ngọc Ánh']
# ['Đinh Bích Hảo']
# ['Đặng Thị Thu Hiền']
# ['Bùi Thị Hải Yến']
# ['Nguyễn Thị Nhàn']
# ['Phạm Thị Minh Thu']
# ['Võ Thị Lan Phương']
# ['Nguyễn Thị Lan Phương']
# ['Hà Thị Hương']
# ['Đinh Thị Kim Dung']
# ['Hoàng Thị Ngọc Hà']
# ['Bùi Thị Kim Cúc']
# ['Nguyễn Thiết Kế']
# ['Phạm Thị Thanh']
# ['Đặng Thị Thu Hà']
# ['Nguyễn Tất Thắng']
# ['Mai Thị Thu Hân']
# ['Dương Thị Ngọc Anh']
# ['Nguyễn Thị Mỹ Hạnh']
# ['Hoàng Thị Tuyết']
# ['Nguyễn Thị Thúy Huyền']
# ['Nguyễn Thị Hoàng Huế']
# ['Đinh Thị Thùy Linh']
# ['Nguyễn Thị Huệ']
# ['Phạm Đức Thuận']
# ['Nguyễn Thị Miền']
# ['Phạm Thanh Tâm']
# ['Nguyễn Thị Lệ Thu']
# ['Đinh Thị Thu Huyền']
# ['Đặng Thanh Điềm']
# ['Bùi Thị Nguyên']
# ['Nguyễn Thị Ánh Dương']
# ['Nguyễn Thị Bích Ngọc']
# ['Phạm Thị Khánh Quỳnh']
# ['Nguyễn Thị Hồng Lý']
# ['Đặng Thị Thu Hà']
# ['Đinh Thị Thanh Huyền']
# ['Vũ Thị Phượng']
# ['Lê Thị Uyên']
# ['Đặng Hà Quyên']
# ['Hà Thị Minh Nga']
# ['Nguyễn Thị Bích Dung']
# ['Vũ Thị Vân Huyền']
# ['Lê Thị Liễu']
# ['Phan Thị Hằng Nga']
# ['Đinh Thị Thúy']
# ['Nguyễn Hải Biên']
# ['Nguyễn Thùy Dương']
# ['Vũ Thị Minh Huyền']
# ['Đinh Thị Thủy']
# ['Hoàng Việt Hưng']
# ['Lương Thu Giang']
# ['Ngô Thị Hằng']
# ['Phạm Thị Hương']
# ['Bùi Thị Nhung']
# ['Tạ Hoàng Minh']
# ['Vũ Thị Diệu Thúy']
# ['Đinh Thị Hồng Loan']
# ['Trương Hải Yến']
# ['Nguyễn Thị Hương Lan']
# ['Phạm Thị Thu Hiền']
# ['Mai Thị Ánh Hồng']
# ['Phạm Thị Thanh Mai']
# ['Vũ Thị Thúy Ngà']
# ['Phạm Thị Tuyết']
# ['Nguyễn Thị Hiền']
# ['Bùi Thị Kim Phụng']
# ['Bùi Hương Giang']
# ['Hoàng Thị Hường']
# ['Lê Thị Thu Hương']
# ['Phạm Văn Thiên']
# ['Tống Thị Kim Anh']
# ['Dương Thu Hương']
# ['Bùi Thị Hồng']
# ['Đỗ Hồng Lĩnh']
# ['Đinh Tiến Thành']
# ['Lê Thị Tâm']
# ['Nguyễn Thi Loan']
# ['Lưu Thanh Ngọc']
# ['Hoàng Thị Bằng']
# ['Bùi Thùy Liên']
# ['Nguyễn Thị Tố Uyên']
# ['Bùi Thị Phương']
# ['Nguyễn Thị Mỳ']
# ['Trần Thị Thanh Phương']
# ['Lê Thị Thu Thủy']
# ['Đinh Bá Hòe']
# ['Hoàng Phúc Ngân']
# ['Trần Ngọc Tú']
# ['Nguyễn Thị Thanh Nhàn']
# ['Phạm Thị Thùy Dung']
# ['Bùi Thị Tươi']
# ['Lương Thị Hoàng Ngân']
# ['Trần Thị Phường']
# ['Đinh Hoài Thu']
# ['Nguyễn Trọng Tâm']
# ['Vũ Thị Phượng']
# ['Vũ Thị Hồng']
# ['Nguyễn Thị Thịnh']
# ['Phạm Thị Trúc']
# ['Đoàn Thị Hoa']
# ['Bùi thị Kim Phương']
# ['Đoàn Thị Thơm']
# ['Đinh Thị Hoa']
# ['Nguyễn Văn Hiếu']
# ['Phạm Thu Quỳnh']
# ['Trần Thị Tân']
# ['Phạm Thanh Xuân']
# ['Vũ Thị Hương Giang']
# ['Vũ Tuệ Minh']
# ['Nguyễn Thị Hào']
# ['Bùi Thị Thu Hiền']
# ['Lê Thị Lan Anh']
# ['Phan Thị Thu Nhài']
# ['Phạm Thành Trung']
# ['Đỗ Thị Yên']
# ['Nguyễn Thúy Mai']
# ['Nguyễn Thị Thu Dung']
# ['Đào Thị Thu Phương']
# ['Nguyễn Thị Thu Thủy']
# ['Nguyễn Thị Liên']
# ['Bùi Thị Tuyết']
# ['Nguyễn Thị Thu Hà']
# ['Bùi Thị Thu Hoài']
# ['Đỗ Thị Thùy Linh']
# ['Dương Trọng Hạnh']
# ['Phạm Thị Ngà']
# ['Hoàng Cao Minh']
# ['Trần Thu Thủy']
# ['Phạm Thị Yến']
# ['Đỗ Quang Đạt']
# ['Phạm Thị Thanh Hà']
# ['Đinh Công Quyền']
# ['Đỗ Thị Tươi']
# ['Trịnh Thị Ngân Phương']
# ['Nguyễn Thị Trang Nhung']
# ['Đinh Thị Hà']
# ['Trần Thanh Tâm']
# ['Dương Thị Thúy Hằng']
# ['Nguyễn Thị Thu Hà']
# ['Hoàng Ngọc Mai']
